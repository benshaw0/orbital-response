# %%
import json
import os
import numpy as np
from PIL import Image, ImageDraw
from tqdm import tqdm
from pathlib import Path
import shutil

# %%
def load_shapes_from_json(json_path):
    with open(json_path, "r") as f:
        data = json.load(f)

    shapes = []
    if "features" in data and "xy" in data["features"]:
        for item in data["features"]["xy"]:
            try:
                polygon = wkt.loads(item["wkt"])
                subtype = item.get("properties", {}).get("subtype", "no-damage")
                class_id = DAMAGE_MAPPING.get(subtype, 0)
                shapes.append((polygon, class_id))
            except Exception as e:
                print(f"Error at json file: {json_path}: {e}")
                continue
    return data

# %%
json_path = "../data/data_secondary_unet/split/train/_annotations.coco.json"

data = load_shapes_from_json(json_path)

# %%
#data['annotations']

# %% [markdown]
# ### Using the following categories:
# **0: No Building
# 1: Building - No Damage
# 2: Building - Damage**

# %%
split = ['train','test','val']

for split in split:
    json_path = f"../data/data_secondary_unet/split/{split}/_annotations.coco.json"
    output_mask_dir = f"../data/data_secondary_unet/split/{split}/masks"
    mask_size = (1024, 1024)

    with open(json_path, 'r') as f:
        coco = json.load(f)

    images = {img['id']: img for img in coco['images']}
    annotations = coco['annotations']

    os.makedirs(output_mask_dir, exist_ok=True)

    image_to_annotations = {}
    for ann in annotations:
        image_id = ann['image_id']
        image_to_annotations.setdefault(image_id, []).append(ann)

    def draw_mask(anns, size):
        mask = Image.new("L", size, 0)
        draw = ImageDraw.Draw(mask)

        for ann in anns:
            category_id = ann['category_id']
            segs = ann['segmentation']
            for seg in segs:
                poly = [(seg[i], seg[i + 1]) for i in range(0, len(seg), 2)]
                draw.polygon(poly, outline=category_id, fill=category_id)

        return np.array(mask, dtype=np.uint8)


    for image_id, image_info in tqdm(images.items()):
        filename = image_info['file_name']
        width, height = image_info['width'], image_info['height']

        anns = image_to_annotations.get(image_id, [])
        mask_array = draw_mask(anns, size=(width, height))

        # Save the mask
        out_path = os.path.join(output_mask_dir, filename.replace('.jpg', '_mask.png'))
        Image.fromarray(mask_array).save(out_path)
# Out:
# 100%|██████████| 70/70 [00:00<00:00, 197.29it/s]
# 100%|██████████| 37/37 [00:00<00:00, 230.25it/s]
# 100%|██████████| 37/37 [00:00<00:00, 234.32it/s]

# %%
import os
from pathlib import Path
import shutil

split = ['train','test','val']

for split in split:
    # Paths
    mask_dir = Path(f"../data/data_secondary_unet/split/{split}/masks")
    pre_image_dir = Path("../data/data_secondary_unet/raw/pre")
    output_dir = Path(f"../data/data_secondary_unet/split/{split}/pre_images")
    output_dir.mkdir(parents=True, exist_ok=True)

    for mask_file in os.listdir(mask_dir):
        if not mask_file.endswith("_mask.png"):
            continue

        # Strip the '_mask.png' suffix and split before '_png.rf'
        try:
            base_name = mask_file.replace("_mask.png", "")
            tile_id = base_name.split("_png.rf")[0]  # e.g. 'gaza_city_jabalya_1_1'
            pre_filename = f"{tile_id}_pre.png"
            pre_path = pre_image_dir / pre_filename

            if pre_path.exists():
                shutil.copy(pre_path, output_dir / pre_filename)
            else:
                print(f"Missing pre-disaster image for: {tile_id}")
        except Exception as e:
            print(f"Error processing {mask_file}: {e}")

# %%
import os
import shutil
from pathlib import Path

    # Define paths
split = ['train','test','val']

for split in split:
    base_dir = Path(f"../data/data_secondary_unet/split/{split}")
    pre_dir = base_dir / "pre_images"
    post_dir = base_dir / "post_images"
    output_dir = base_dir / "images"

    # Create output directory if it doesn't exist
    output_dir.mkdir(exist_ok=True)

    # Step 1: Get all pre-disaster base names
    pre_images = list(pre_dir.glob("*.png"))

    for pre_path in pre_images:
        # Extract the base key: beit_hanoun_0_0
        base_key = pre_path.stem.replace("_pre", "")

        # Define target filenames
        pre_target = output_dir / f"{base_key}_pre_disaster.png"
        post_target = output_dir / f"{base_key}_post_disaster.png"

        # Try to find matching post-disaster image (contains base_key)
        matching_post = list(post_dir.glob(f"{base_key}_*.jpg"))

        if matching_post:
            # Convert post image to .png
            post_img = matching_post[0]
            from PIL import Image
            img = Image.open(post_img).convert("RGB")
            img.save(post_target)

            # Copy pre image as-is (already .png)
            shutil.copy(pre_path, pre_target)

            print(f"Processed: {base_key}")
        else:
            print(f"No matching post image for: {base_key}")
# Out:
# Processed: gaza_city_jabalya_4_3
# Processed: gaza_city_jabalya_3_1
# Processed: beit_hanoun_5_1
# Processed: beit_hanoun_0_4
# Processed: gaza_city_jabalya_5_0
# Processed: beit_hanoun_3_0
# Processed: gaza_city_jabalya_2_2
# Processed: beit_hanoun_0_5
# Processed: beit_hanoun_3_1
# Processed: gaza_city_jabalya_2_3
# Processed: beit_hanoun_4_3
# Processed: beit_hanoun_2_2
# Processed: gaza_city_jabalya_0_4
# Processed: beit_hanoun_5_0
# Processed: beit_hanoun_3_3
# Processed: gaza_city_shejaiya_5_4
# Processed: gaza_city_jabalya_2_1
# Processed: khan_yunis_3_0
# Processed: beit_hanoun_1_4
# Processed: gaza_city_shejaiya_0_1
# Processed: beit_hanoun_5_2
# Processed: gaza_city_jabalya_3_2
# Processed: beit_hanoun_2_1
# Processed: beit_hanoun_1_5
# Processed: gaza_city_shejaiya_4_6
# Processed: gaza_city_shejaiya_0_0
# Processed: beit_hanoun_5_3
# Processed: beit_hanoun_3_2
# Processed: beit_hanoun_4_0
# Processed: gaza_city_jabalya_2_0
# Processed: gaza_city_jabalya_1_4
# Processed: gaza_city_shejaiya_1_6
# Processed: beit_hanoun_4_5
# Processed: gaza_city_jabalya_2_5
# Processed: gaza_city_jabalya_1_1
# Processed: beit_hanoun_0_3
# Processed: gaza_city_jabalya_3_6
# Processed: beit_hanoun_6_2
# Processed: beit_hanoun_2_4
# Processed: gaza_city_jabalya_4_4
# Processed: gaza_city_shejaiya_4_3
# Processed: gaza_city_jabalya_0_3
# Processed: beit_hanoun_6_3
# Processed: gaza_city_jabalya_4_5
# Processed: beit_hanoun_2_5
# Processed: beit_hanoun_1_1
# Processed: gaza_city_jabalya_2_4
# Processed: beit_hanoun_4_4
# Processed: gaza_city_jabalya_1_0
# Processed: gaza_city_jabalya_6_2
# Processed: beit_hanoun_0_2
# Processed: gaza_city_shejaiya_5_1
# Processed: beit_hanoun_6_1
# Processed: gaza_city_jabalya_3_5
# Processed: beit_hanoun_1_3
# Processed: gaza_city_shejaiya_2_1
# Processed: gaza_city_jabalya_1_2
# Processed: gaza_city_jabalya_2_6
# Processed: gaza_city_shejaiya_1_5
# Processed: gaza_city_jabalya_6_0
# Processed: gaza_city_shejaiya_5_3
# Processed: beit_hanoun_0_0
# Processed: beit_hanoun_3_4
# Processed: gaza_city_jabalya_5_4
# Processed: gaza_city_jabalya_1_3
# Processed: beit_hanoun_0_1
# Processed: gaza_city_jabalya_6_1
# Processed: gaza_city_jabalya_0_0
# Processed: khan_yunis_1_1
# Processed: gaza_city_shejaiya_4_1
# Processed: khan_yunis_5_2
# Processed: rafah_0_5
# Processed: khan_yunis_2_0
# Processed: nuseirat_camp_4_2
# Processed: gaza_city_shejaiya_6_3
# Processed: gaza_city_jabalya_1_6
# Processed: gaza_city_shejaiya_1_1
# Processed: beit_hanoun_4_2
# Processed: gaza_city_shejaiya_2_4
# Processed: nuseirat_camp_5_0
# Processed: khan_yunis_5_3
# Processed: nuseirat_camp_3_1
# Processed: khan_yunis_4_2
# Processed: beit_hanoun_4_1
# Processed: rafah_4_0
# Processed: nuseirat_camp_3_2
# Processed: khan_yunis_6_4
# Processed: gaza_city_jabalya_4_1
# Processed: nuseirat_camp_0_6
# Processed: rafah_5_2
# Processed: nuseirat_camp_5_6
# Processed: khan_yunis_0_0
# Processed: gaza_city_shejaiya_5_0
# Processed: gaza_city_shejaiya_3_1
# Processed: khan_yunis_5_5
# Processed: beit_hanoun_1_0
# Processed: gaza_city_shejaiya_3_0
# Processed: rafah_4_5
# Processed: khan_yunis_5_4
# Processed: khan_yunis_0_1
# Processed: khan_yunis_1_0
# Processed: khan_yunis_5_6
# Processed: nuseirat_camp_6_1
# Processed: nuseirat_camp_6_0
# Processed: rafah_5_5
# Processed: beit_hanoun_1_2
# Processed: khan_yunis_6_3
# Processed: nuseirat_camp_3_0
# Processed: beit_hanoun_2_3
# Processed: nuseirat_camp_6_5
# Processed: rafah_5_1
# Processed: gaza_city_jabalya_4_2
# Processed: rafah_3_0
# Processed: nuseirat_camp_2_0
# Processed: nuseirat_camp_1_4
# Processed: nuseirat_camp_6_6
# Processed: gaza_city_jabalya_4_0
# Processed: beit_hanoun_2_0
# Processed: rafah_3_2
# Processed: gaza_city_jabalya_0_6
# Processed: gaza_city_jabalya_3_3
# Processed: nuseirat_camp_5_3
# Processed: rafah_2_5
# Processed: nuseirat_camp_2_4
# Processed: rafah_3_6
# Processed: gaza_city_jabalya_0_2
# Processed: khan_yunis_1_2
# Processed: rafah_0_3
# Processed: nuseirat_camp_3_6
# Processed: nuseirat_camp_1_1
# Processed: rafah_0_1
# Processed: nuseirat_camp_4_6
# Processed: gaza_city_shejaiya_4_0
# Processed: nuseirat_camp_5_5
# Processed: khan_yunis_4_5
# Processed: rafah_5_4
# Processed: nuseirat_camp_5_4
# Processed: khan_yunis_0_2
# Processed: rafah_6_1
# Processed: khan_yunis_4_4
# Processed: beit_hanoun_6_0
# Processed: gaza_city_jabalya_3_4
# Processed: rafah_3_4
# Processed: beit_hanoun_5_4

# %%
import os
import re

splits = ['train', 'test', 'val']

for split in splits:
    # Folder containing your mask files
    folder = f'../data/data_secondary_unet/split/{split}/masks'

    # Pattern to match and remove the '.png.rf.<hash>' part before '_mask.png'
    pattern = re.compile(r'(.*)_png\.rf\.[a-f0-9]+(_mask\.png)')

    for filename in os.listdir(folder):
        # Only process PNG files
        if filename.endswith('_mask.png'):
            match = pattern.match(filename)
            if match:
                new_name = match.group(1) + match.group(2)
                old_path = os.path.join(folder, filename)
                new_path = os.path.join(folder, new_name)
                print(f'Renaming:\n  {filename}\n  -> {new_name}')
                os.rename(old_path, new_path)
# Out:
# Renaming:
#   gaza_city_jabalya_1_0_png.rf.6cf2144567456736b31a7cd85d38ed64_mask.png
#   -> gaza_city_jabalya_1_0_mask.png
# Renaming:
#   beit_hanoun_5_0_png.rf.1248d03f32112e8dd06ff4103e418e6a_mask.png
#   -> beit_hanoun_5_0_mask.png
# Renaming:
#   beit_hanoun_3_4_png.rf.c39a6b03ef7b3eb584ecf8e4b41189eb_mask.png
#   -> beit_hanoun_3_4_mask.png
# Renaming:
#   beit_hanoun_0_4_png.rf.ce268a5fa5cde69c29deb55638da380b_mask.png
#   -> beit_hanoun_0_4_mask.png
# Renaming:
#   khan_yunis_1_1_png.rf.b53ea5e8b2a0d2ee37e883665fa1d0ba_mask.png
#   -> khan_yunis_1_1_mask.png
# Renaming:
#   beit_hanoun_5_3_png.rf.1357b553568e3461af2fa6fad2d66aaa_mask.png
#   -> beit_hanoun_5_3_mask.png
# Renaming:
#   gaza_city_jabalya_3_2_png.rf.a01cb095fc1bfc90deb20df50db4ca1f_mask.png
#   -> gaza_city_jabalya_3_2_mask.png
# Renaming:
#   gaza_city_jabalya_0_0_png.rf.85aeb6800a1a1d0ad4339b22df9e8604_mask.png
#   -> gaza_city_jabalya_0_0_mask.png
# Renaming:
#   gaza_city_jabalya_1_4_png.rf.c61914a56c1e685b9046a36f63c191ba_mask.png
#   -> gaza_city_jabalya_1_4_mask.png
# Renaming:
#   beit_hanoun_1_1_png.rf.c63eb6cb293b7de4aaf3e34b9979a1a0_mask.png
#   -> beit_hanoun_1_1_mask.png
# Renaming:
#   beit_hanoun_1_4_png.rf.78dc7c463581185d96adcb7cb886d897_mask.png
#   -> beit_hanoun_1_4_mask.png
# Renaming:
#   beit_hanoun_5_2_png.rf.bfb09daa3720ef8ce055f211f57945dd_mask.png
#   -> beit_hanoun_5_2_mask.png
# Renaming:
#   beit_hanoun_5_1_png.rf.6e1d9757cc64eb708fb209fda9d16228_mask.png
#   -> beit_hanoun_5_1_mask.png
# Renaming:
#   gaza_city_shejaiya_1_5_png.rf.00b45ebc67e5ae2b0989209a1154737e_mask.png
#   -> gaza_city_shejaiya_1_5_mask.png
# Renaming:
#   gaza_city_jabalya_2_1_png.rf.3c95efed17042089b126f2cffe17669c_mask.png
#   -> gaza_city_jabalya_2_1_mask.png
# Renaming:
#   beit_hanoun_2_4_png.rf.5b83b1d6cf5a2dc728f255c1cf35c712_mask.png
#   -> beit_hanoun_2_4_mask.png
# Renaming:
#   gaza_city_jabalya_3_1_png.rf.823013bc9586d0d7632512b1e6aec03d_mask.png
#   -> gaza_city_jabalya_3_1_mask.png
# Renaming:
#   gaza_city_shejaiya_1_6_png.rf.e3d2f8bec07717a6f4723667fb600f85_mask.png
#   -> gaza_city_shejaiya_1_6_mask.png
# Renaming:
#   gaza_city_jabalya_2_5_png.rf.44712a756e5bfaa7a82085f228604cca_mask.png
#   -> gaza_city_jabalya_2_5_mask.png
# Renaming:
#   gaza_city_jabalya_3_6_png.rf.b767fe1a6fd5f13e91f5820d562b9888_mask.png
#   -> gaza_city_jabalya_3_6_mask.png
# Renaming:
#   gaza_city_shejaiya_5_4_png.rf.97e3e808d2380c4e72aedf694d18d47a_mask.png
#   -> gaza_city_shejaiya_5_4_mask.png
# Renaming:
#   beit_hanoun_3_3_png.rf.5e7afc5df305d44f0ffc986b472ca467_mask.png
#   -> beit_hanoun_3_3_mask.png
# Renaming:
#   beit_hanoun_3_0_png.rf.b24e32ce4937047001415649dfe3ccdd_mask.png
#   -> beit_hanoun_3_0_mask.png
# Renaming:
#   beit_hanoun_0_2_png.rf.ff7c93e58ca5efc02dbc8f914c8cd340_mask.png
#   -> beit_hanoun_0_2_mask.png
# Renaming:
#   gaza_city_jabalya_5_0_png.rf.d8b9fae9df180f75be51b8ed9917d7c1_mask.png
#   -> gaza_city_jabalya_5_0_mask.png
# Renaming:
#   beit_hanoun_3_2_png.rf.9501b1e8eea96f3cc04648b67b12cdf5_mask.png
#   -> beit_hanoun_3_2_mask.png
# Renaming:
#   gaza_city_jabalya_2_2_png.rf.76405bca76c7f281d26a3f398ada5f04_mask.png
#   -> gaza_city_jabalya_2_2_mask.png
# Renaming:
#   gaza_city_shejaiya_4_1_png.rf.5727b2dac494f8c302a8fcf15f335587_mask.png
#   -> gaza_city_shejaiya_4_1_mask.png
# Renaming:
#   gaza_city_jabalya_2_4_png.rf.27e84c9486abf5e0604cb3c1a4d56a64_mask.png
#   -> gaza_city_jabalya_2_4_mask.png
# Renaming:
#   beit_hanoun_0_5_png.rf.bd94406a3f62c84254ec308240b87562_mask.png
#   -> beit_hanoun_0_5_mask.png
# Renaming:
#   beit_hanoun_6_2_png.rf.4036880a70952ead46dff0774410d5f9_mask.png
#   -> beit_hanoun_6_2_mask.png
# Renaming:
#   gaza_city_jabalya_1_3_png.rf.3cce956181bc802b04418bfea9fb0a21_mask.png
#   -> gaza_city_jabalya_1_3_mask.png
# Renaming:
#   gaza_city_jabalya_5_4_png.rf.38b0ccc2597d037eece86c74c69861d9_mask.png
#   -> gaza_city_jabalya_5_4_mask.png
# Renaming:
#   gaza_city_jabalya_2_6_png.rf.1512ab6c5023af4d5a18ce6b06e32c97_mask.png
#   -> gaza_city_jabalya_2_6_mask.png
# Renaming:
#   beit_hanoun_2_2_png.rf.377147ed2af19898332bfe9369927c6e_mask.png
#   -> beit_hanoun_2_2_mask.png
# Renaming:
#   gaza_city_shejaiya_4_6_png.rf.7aaa0099d7872f6801e31e332ae35d11_mask.png
#   -> gaza_city_shejaiya_4_6_mask.png
# Renaming:
#   beit_hanoun_1_3_png.rf.681b211fa220b59b13a2827064aa4ab0_mask.png
#   -> beit_hanoun_1_3_mask.png
# Renaming:
#   gaza_city_jabalya_0_3_png.rf.fe761be4e1454176c021008a6850e449_mask.png
#   -> gaza_city_jabalya_0_3_mask.png
# Renaming:
#   gaza_city_jabalya_4_4_png.rf.3cb7cc8e71281e77c0685caf25ef7738_mask.png
#   -> gaza_city_jabalya_4_4_mask.png
# Renaming:
#   gaza_city_jabalya_4_5_png.rf.fbbb6f4176e4be5dae4e728955cb9e6c_mask.png
#   -> gaza_city_jabalya_4_5_mask.png
# Renaming:
#   gaza_city_shejaiya_5_3_png.rf.63ec965a4fa7337b54aebd7e22bd1826_mask.png
#   -> gaza_city_shejaiya_5_3_mask.png
# Renaming:
#   gaza_city_shejaiya_2_1_png.rf.4f1dbb5b1ef37a09784215ecd2eb00f3_mask.png
#   -> gaza_city_shejaiya_2_1_mask.png
# Renaming:
#   beit_hanoun_1_5_png.rf.0a7b8c4dbf62ac519ffd8a8b6e045896_mask.png
#   -> beit_hanoun_1_5_mask.png
# Renaming:
#   gaza_city_jabalya_6_2_png.rf.ddf90048b74d4afe8c563ead03785e29_mask.png
#   -> gaza_city_jabalya_6_2_mask.png
# Renaming:
#   beit_hanoun_2_5_png.rf.29c9fea9748091b4f3dd01e422e6c521_mask.png
#   -> beit_hanoun_2_5_mask.png
# Renaming:
#   gaza_city_jabalya_2_3_png.rf.cacf45c7eca1a3bdaa8925a30ad5df33_mask.png
#   -> gaza_city_jabalya_2_3_mask.png
# Renaming:
#   gaza_city_jabalya_6_0_png.rf.c962ee7e2951ef15d1b3b75f9656ad99_mask.png
#   -> gaza_city_jabalya_6_0_mask.png
# Renaming:
#   gaza_city_jabalya_0_4_png.rf.a5e6dac5d50d38b9b06187af1bf13666_mask.png
#   -> gaza_city_jabalya_0_4_mask.png
# Renaming:
#   beit_hanoun_2_1_png.rf.5deaa08a83562c607268d16c760aeed7_mask.png
#   -> beit_hanoun_2_1_mask.png
# Renaming:
#   gaza_city_jabalya_6_1_png.rf.a40e6cd32088a25613ba4cf44878a520_mask.png
#   -> gaza_city_jabalya_6_1_mask.png
# Renaming:
#   gaza_city_shejaiya_5_1_png.rf.b382c4455a332e80c9c9b5ef29518786_mask.png
#   -> gaza_city_shejaiya_5_1_mask.png
# Renaming:
#   beit_hanoun_0_0_png.rf.4fa3b42a459b9335c122cc7165890ea0_mask.png
#   -> beit_hanoun_0_0_mask.png
# Renaming:
#   gaza_city_jabalya_1_2_png.rf.812d7b78296ca2d78837d4006da1ccbd_mask.png
#   -> gaza_city_jabalya_1_2_mask.png
# Renaming:
#   beit_hanoun_0_1_png.rf.f426fb652d89a208ec7c4bd13c87320d_mask.png
#   -> beit_hanoun_0_1_mask.png
# Renaming:
#   beit_hanoun_6_1_png.rf.d3b9b2863d55a5a1d5595ea2dd45ff42_mask.png
#   -> beit_hanoun_6_1_mask.png
# Renaming:
#   beit_hanoun_4_5_png.rf.3afd3747eb8792acd9760744b7f5a6af_mask.png
#   -> beit_hanoun_4_5_mask.png
# Renaming:
#   beit_hanoun_4_3_png.rf.5d83be11372e03022abf4c84d1797980_mask.png
#   -> beit_hanoun_4_3_mask.png
# Renaming:
#   beit_hanoun_6_3_png.rf.546765b639a89a32f3731ba9d227b5cc_mask.png
#   -> beit_hanoun_6_3_mask.png
# Renaming:
#   gaza_city_shejaiya_0_0_png.rf.9b2b17c09c0355c7fdae8137ef56c50c_mask.png
#   -> gaza_city_shejaiya_0_0_mask.png
# Renaming:
#   gaza_city_shejaiya_0_1_png.rf.16cdf28f5b7153c1be7cde41a4cd8bbf_mask.png
#   -> gaza_city_shejaiya_0_1_mask.png
# Renaming:
#   beit_hanoun_3_1_png.rf.ae0b3dc176b850fe562113f0eb82ec5b_mask.png
#   -> beit_hanoun_3_1_mask.png
# Renaming:
#   gaza_city_jabalya_1_1_png.rf.85556d7daad781e547187fbd32b45536_mask.png
#   -> gaza_city_jabalya_1_1_mask.png
# Renaming:
#   beit_hanoun_4_4_png.rf.d2839974e52115373e55fd5f1c0afc1b_mask.png
#   -> beit_hanoun_4_4_mask.png
# Renaming:
#   beit_hanoun_4_0_png.rf.be8ff7d532f4dd2846c3c96c413c79a3_mask.png
#   -> beit_hanoun_4_0_mask.png
# Renaming:
#   gaza_city_jabalya_2_0_png.rf.4702ab8e8aa9a3d1aed87946295a8d6c_mask.png
#   -> gaza_city_jabalya_2_0_mask.png
# Renaming:
#   khan_yunis_3_0_png.rf.21a38689e29f05bfa997170e070b7374_mask.png
#   -> khan_yunis_3_0_mask.png
# Renaming:
#   gaza_city_jabalya_4_3_png.rf.ba9b3226b2c1ce34adde404b0d7f5994_mask.png
#   -> gaza_city_jabalya_4_3_mask.png
# Renaming:
#   beit_hanoun_0_3_png.rf.45878eadee44439579aac8c5ad95b03b_mask.png
#   -> beit_hanoun_0_3_mask.png
# Renaming:
#   gaza_city_jabalya_3_5_png.rf.08e4fcd37958ea989f8587470436ee31_mask.png
#   -> gaza_city_jabalya_3_5_mask.png
# Renaming:
#   gaza_city_shejaiya_4_3_png.rf.1a0ebff716db8d856e4bac87cece1e2a_mask.png
#   -> gaza_city_shejaiya_4_3_mask.png
# Renaming:
#   rafah_0_5_png.rf.3031ca38efaa59c13172aade0382316c_mask.png
#   -> rafah_0_5_mask.png
# Renaming:
#   khan_yunis_5_6_png.rf.c52ed00d06de9566d3c1286bf946f0d0_mask.png
#   -> khan_yunis_5_6_mask.png
# Renaming:
#   beit_hanoun_1_2_png.rf.434dbdeddae5b3baa64b2547d433bdb5_mask.png
#   -> beit_hanoun_1_2_mask.png
# Renaming:
#   rafah_4_0_png.rf.e2313cdc71b7fd6a1f82d59dd3549335_mask.png
#   -> rafah_4_0_mask.png
# Renaming:
#   nuseirat_camp_3_2_png.rf.da3e08ae746623e727064ffdf150440d_mask.png
#   -> nuseirat_camp_3_2_mask.png
# Renaming:
#   gaza_city_jabalya_4_1_png.rf.cb41151947a3a20c4141f060e4aceb28_mask.png
#   -> gaza_city_jabalya_4_1_mask.png
# Renaming:
#   nuseirat_camp_5_6_png.rf.9aba101adf315e9ecd1dde093841a825_mask.png
#   -> nuseirat_camp_5_6_mask.png
# Renaming:
#   gaza_city_shejaiya_6_3_png.rf.23f0e3da789c526d5e832b0601484727_mask.png
#   -> gaza_city_shejaiya_6_3_mask.png
# Renaming:
#   nuseirat_camp_4_2_png.rf.e47f3e5f67cd18e60b67fa44862b9b34_mask.png
#   -> nuseirat_camp_4_2_mask.png
# Renaming:
#   nuseirat_camp_3_1_png.rf.6c659ffd01fea56612086a4691336e82_mask.png
#   -> nuseirat_camp_3_1_mask.png
# Renaming:
#   gaza_city_shejaiya_2_4_png.rf.d6fc74f4017b378be5d14967048ff47a_mask.png
#   -> gaza_city_shejaiya_2_4_mask.png
# Renaming:
#   beit_hanoun_4_2_png.rf.ce35be80b093ba7a25c0f24903e9ed01_mask.png
#   -> beit_hanoun_4_2_mask.png
# Renaming:
#   rafah_4_5_png.rf.0254006baee9a70469d3557616f94de1_mask.png
#   -> rafah_4_5_mask.png
# Renaming:
#   nuseirat_camp_6_0_png.rf.3e381992c7ba0f211716622f2f0abfb7_mask.png
#   -> nuseirat_camp_6_0_mask.png
# Renaming:
#   khan_yunis_1_0_png.rf.db2c40970faa3e67861765cce2cec46d_mask.png
#   -> khan_yunis_1_0_mask.png
# Renaming:
#   gaza_city_shejaiya_3_1_png.rf.280db9c6dd05854baa6841438aca72e8_mask.png
#   -> gaza_city_shejaiya_3_1_mask.png
# Renaming:
#   khan_yunis_5_5_png.rf.df7ac802641c2ec2ff840e0ac04e068d_mask.png
#   -> khan_yunis_5_5_mask.png
# Renaming:
#   beit_hanoun_4_1_png.rf.896a809e8e18306528f949aa09e3ef0c_mask.png
#   -> beit_hanoun_4_1_mask.png
# Renaming:
#   nuseirat_camp_5_0_png.rf.b435ceb4cd3c0ccee5753b5c2cac692b_mask.png
#   -> nuseirat_camp_5_0_mask.png
# Renaming:
#   nuseirat_camp_6_1_png.rf.d66a684675fd2f3ff80d7a1e338ca810_mask.png
#   -> nuseirat_camp_6_1_mask.png
# Renaming:
#   nuseirat_camp_0_6_png.rf.81feac50f250f081a83b59e37c477e60_mask.png
#   -> nuseirat_camp_0_6_mask.png
# Renaming:
#   rafah_5_5_png.rf.f51340c936a01081207a8d14ba3ab207_mask.png
#   -> rafah_5_5_mask.png
# Renaming:
#   khan_yunis_4_2_png.rf.b8589eae2bf94a30303f1f824c9b00dc_mask.png
#   -> khan_yunis_4_2_mask.png
# Renaming:
#   gaza_city_shejaiya_5_0_png.rf.937d1ccceb9f246338318edf506ad0f8_mask.png
#   -> gaza_city_shejaiya_5_0_mask.png
# Renaming:
#   gaza_city_shejaiya_1_1_png.rf.2802c8d5c99ac605df32402721a175fb_mask.png
#   -> gaza_city_shejaiya_1_1_mask.png
# Renaming:
#   khan_yunis_6_4_png.rf.93b3a8dc3b94c7fea7ec19a7c38892c0_mask.png
#   -> khan_yunis_6_4_mask.png
# Renaming:
#   khan_yunis_0_1_png.rf.6526060a535a52eff3981d49ecd5fe62_mask.png
#   -> khan_yunis_0_1_mask.png
# Renaming:
#   khan_yunis_0_0_png.rf.c2bd1a064fe546055ec247fc700afeae_mask.png
#   -> khan_yunis_0_0_mask.png
# Renaming:
#   khan_yunis_5_3_png.rf.8071d54d6a0933ba361c7d859e359857_mask.png
#   -> khan_yunis_5_3_mask.png
# Renaming:
#   khan_yunis_6_3_png.rf.f721b199770bf4d4530b8eb728bb58d6_mask.png
#   -> khan_yunis_6_3_mask.png
# Renaming:
#   gaza_city_jabalya_1_6_png.rf.3e410135281aab1e6df20793560b9b50_mask.png
#   -> gaza_city_jabalya_1_6_mask.png
# Renaming:
#   khan_yunis_5_2_png.rf.755e8926203d49cabb12effeebccb1e0_mask.png
#   -> khan_yunis_5_2_mask.png
# Renaming:
#   gaza_city_shejaiya_3_0_png.rf.cb8477f5e2867e9e46d6c576f943e20f_mask.png
#   -> gaza_city_shejaiya_3_0_mask.png
# Renaming:
#   rafah_5_2_png.rf.6d1db02f71c5fc76ce2642120c704829_mask.png
#   -> rafah_5_2_mask.png
# Renaming:
#   beit_hanoun_1_0_png.rf.b4a63392fe192d1c2703118681b357cb_mask.png
#   -> beit_hanoun_1_0_mask.png
# Renaming:
#   khan_yunis_5_4_png.rf.fec4d1fa9f7851300f0322ff09ca071b_mask.png
#   -> khan_yunis_5_4_mask.png
# Renaming:
#   khan_yunis_2_0_png.rf.720e0820c55cf921b99bd998cae287d7_mask.png
#   -> khan_yunis_2_0_mask.png
# Renaming:
#   gaza_city_jabalya_0_2_png.rf.42c872ce7b67a62c34281797c2a5f6fa_mask.png
#   -> gaza_city_jabalya_0_2_mask.png
# Renaming:
#   gaza_city_jabalya_3_4_png.rf.a440ff42bf1c51431042cb5808d2796e_mask.png
#   -> gaza_city_jabalya_3_4_mask.png
# Renaming:
#   rafah_0_3_png.rf.baf051e7bf4e6b374b25f43a75d63f6d_mask.png
#   -> rafah_0_3_mask.png
# Renaming:
#   khan_yunis_0_2_png.rf.c567b418a5c61b7665966a826b60a94d_mask.png
#   -> khan_yunis_0_2_mask.png
# Renaming:
#   nuseirat_camp_2_0_png.rf.b8d3a4a291856409b2cc0e3ee604643b_mask.png
#   -> nuseirat_camp_2_0_mask.png
# Renaming:
#   gaza_city_jabalya_4_0_png.rf.75cbb9017fbe3565504281ee30aea742_mask.png
#   -> gaza_city_jabalya_4_0_mask.png
# Renaming:
#   rafah_3_2_png.rf.6b7d0c75287fdaf01ed24f12d1d38e58_mask.png
#   -> rafah_3_2_mask.png
# Renaming:
#   rafah_0_1_png.rf.5726af58ee516ce212f851561b39b973_mask.png
#   -> rafah_0_1_mask.png
# Renaming:
#   nuseirat_camp_1_4_png.rf.e20ba42223999c025d46961087523693_mask.png
#   -> nuseirat_camp_1_4_mask.png
# Renaming:
#   nuseirat_camp_6_5_png.rf.3dac25b68fe7c4cf23ef7ec2ee26f0a0_mask.png
#   -> nuseirat_camp_6_5_mask.png
# Renaming:
#   nuseirat_camp_5_5_png.rf.7683ed754223c998697d60d8ee721034_mask.png
#   -> nuseirat_camp_5_5_mask.png
# Renaming:
#   khan_yunis_4_5_png.rf.53846f5a5e839cfc2cc0de8f9b85919e_mask.png
#   -> khan_yunis_4_5_mask.png
# Renaming:
#   nuseirat_camp_1_1_png.rf.800340e09efc1169a88aefb36babbc96_mask.png
#   -> nuseirat_camp_1_1_mask.png
# Renaming:
#   gaza_city_jabalya_0_6_png.rf.ca235536a613124f78cc6594ca0a1de9_mask.png
#   -> gaza_city_jabalya_0_6_mask.png
# Renaming:
#   beit_hanoun_2_3_png.rf.1ff2438bfb0feb6c2dbc814591db3260_mask.png
#   -> beit_hanoun_2_3_mask.png
# Renaming:
#   nuseirat_camp_3_0_png.rf.cb9cc545e46612e50662bd7b38bac537_mask.png
#   -> nuseirat_camp_3_0_mask.png
# Renaming:
#   rafah_3_0_png.rf.0d7b7548b55988bf7ffa1e88ef61c984_mask.png
#   -> rafah_3_0_mask.png
# Renaming:
#   gaza_city_jabalya_4_2_png.rf.5e33ad3434585655626b303e58e798fe_mask.png
#   -> gaza_city_jabalya_4_2_mask.png
# Renaming:
#   gaza_city_shejaiya_4_0_png.rf.79d567b3b7c21c653c314d52ac729532_mask.png
#   -> gaza_city_shejaiya_4_0_mask.png
# Renaming:
#   nuseirat_camp_6_6_png.rf.37eddafc64e6ea1b6a4de3fec45431d1_mask.png
#   -> nuseirat_camp_6_6_mask.png
# Renaming:
#   beit_hanoun_6_0_png.rf.15a410d305606e24e925833a3d221c43_mask.png
#   -> beit_hanoun_6_0_mask.png
# Renaming:
#   nuseirat_camp_2_4_png.rf.8c626a891259b3ced382e1097d7ed1b2_mask.png
#   -> nuseirat_camp_2_4_mask.png
# Renaming:
#   beit_hanoun_5_4_png.rf.e1174c1318b8ea60e9cc0807760b9dc9_mask.png
#   -> beit_hanoun_5_4_mask.png
# Renaming:
#   rafah_5_4_png.rf.b5871b16e2ac8f6dfe582c8d942663aa_mask.png
#   -> rafah_5_4_mask.png
# Renaming:
#   rafah_5_1_png.rf.47f7b47c0aa3584f28bb0aab079ce94f_mask.png
#   -> rafah_5_1_mask.png
# Renaming:
#   nuseirat_camp_5_3_png.rf.4fe7428101bbcef8b12857109f709136_mask.png
#   -> nuseirat_camp_5_3_mask.png
# Renaming:
#   rafah_3_4_png.rf.dfe34b8fccf7194aec353cbc171395be_mask.png
#   -> rafah_3_4_mask.png
# Renaming:
#   rafah_3_6_png.rf.433d6d2154d5deaa91faaa607e20f69d_mask.png
#   -> rafah_3_6_mask.png
# Renaming:
#   nuseirat_camp_4_6_png.rf.519f57fe5233f43fed609868e7ea8af1_mask.png
#   -> nuseirat_camp_4_6_mask.png
# Renaming:
#   beit_hanoun_2_0_png.rf.b5933f63fe75deb836d3b7bdc5526347_mask.png
#   -> beit_hanoun_2_0_mask.png
# Renaming:
#   nuseirat_camp_3_6_png.rf.550bd2aea5d3d5cf5bdb41a9eb1e916b_mask.png
#   -> nuseirat_camp_3_6_mask.png
# Renaming:
#   gaza_city_jabalya_3_3_png.rf.c2a0948cf623336523377b8cfc88bbb5_mask.png
#   -> gaza_city_jabalya_3_3_mask.png
# Renaming:
#   nuseirat_camp_5_4_png.rf.1c5cb961378dc4c146815cbe26fcea73_mask.png
#   -> nuseirat_camp_5_4_mask.png
# Renaming:
#   khan_yunis_4_4_png.rf.98c88cc2aa0d80425062eed9aedbfc4d_mask.png
#   -> khan_yunis_4_4_mask.png
# Renaming:
#   rafah_6_1_png.rf.31c989bda906de21b14ca9e0846b6d6b_mask.png
#   -> rafah_6_1_mask.png
# Renaming:
#   khan_yunis_1_2_png.rf.ee1d448ba6891849198184a60914b2eb_mask.png
#   -> khan_yunis_1_2_mask.png
# Renaming:
#   rafah_2_5_png.rf.f6995981c6b8ae2938cdcc361655d18d_mask.png
#   -> rafah_2_5_mask.png
