# %%
import os
import math
import requests
from pathlib import Path
from PIL import Image
from io import BytesIO

# %%
zoom = 18
resolution = "512x512"
scale = 2
grid_radius = 3  # For a 7x7 grid
tile_size_m = 300

# %%
locations = {
    "gaza_city_shejaiya": (31.49944, 34.458220),
    "gaza_city_jabalya": (31.530831, 34.496223),
    "khan_yunis": (31.353261, 34.292597),
    "nuseirat_camp": (31.459875, 34.391665),
    "beit_hanoun": (31.536525, 34.540841),
    "rafah": (31.286419, 34.254626),
}

# %%
output_dir = Path("../data_secondary")
output_dir.mkdir(parents=True, exist_ok=True)

# %%
def mapbox_api(lat, lon, tile_name):
    zoom = 18
    size = (1024, 1024)
    mapbox_token = os.getenv("MAPBOX_API_KEY")

    url = (
        f"https://api.mapbox.com/styles/v1/mapbox/satellite-v9/static/{lon},{lat},{zoom}/{size[0]}x{size[1]}?access_token={mapbox_token}"
    )

    output_dir = Path("../data_secondary/pre")
    output_dir.mkdir(parents=True, exist_ok=True)

    r = requests.get(url)
    response = requests.get(url)
    if response.status_code == 200:
        img = Image.open(BytesIO(response.content))
        img.save(output_dir / tile_name)
        print(f"Saved: {output_dir / tile_name}")
    else:
        print(f"Failed at {lat}, {lon} | Status code: {response.status_code}")

# %%
def meters_per_pixel(lat, zoom, scale=2):
    return (156543.03392 / scale) * math.cos(math.radians(lat)) / (2 ** zoom)

# %%
for city, (center_lat, center_lon) in locations.items():
    mpp = meters_per_pixel(center_lat, zoom)

    deg_per_tile_lat = tile_size_m / 111320
    deg_per_tile_lon = tile_size_m / (111320 * math.cos(math.radians(center_lat)))

    for i in range(-grid_radius, grid_radius + 1):
        for j in range(-grid_radius, grid_radius + 1):
            tile_lat = center_lat + i * deg_per_tile_lat
            tile_lon = center_lon + j * deg_per_tile_lon
            tile_name = f"{city}_{i+grid_radius}_{j+grid_radius}_pre.png"
            mapbox_api(tile_lat, tile_lon, tile_name)
# Out:
# Saved: ../data_secondary/pre/gaza_city_shejaiya_0_0_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_0_1_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_0_2_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_0_3_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_0_4_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_0_5_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_0_6_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_1_0_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_1_1_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_1_2_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_1_3_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_1_4_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_1_5_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_1_6_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_2_0_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_2_1_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_2_2_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_2_3_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_2_4_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_2_5_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_2_6_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_3_0_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_3_1_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_3_2_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_3_3_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_3_4_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_3_5_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_3_6_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_4_0_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_4_1_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_4_2_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_4_3_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_4_4_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_4_5_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_4_6_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_5_0_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_5_1_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_5_2_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_5_3_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_5_4_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_5_5_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_5_6_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_6_0_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_6_1_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_6_2_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_6_3_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_6_4_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_6_5_pre.png
# Saved: ../data_secondary/pre/gaza_city_shejaiya_6_6_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_0_0_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_0_1_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_0_2_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_0_3_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_0_4_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_0_5_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_0_6_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_1_0_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_1_1_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_1_2_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_1_3_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_1_4_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_1_5_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_1_6_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_2_0_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_2_1_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_2_2_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_2_3_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_2_4_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_2_5_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_2_6_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_3_0_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_3_1_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_3_2_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_3_3_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_3_4_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_3_5_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_3_6_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_4_0_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_4_1_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_4_2_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_4_3_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_4_4_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_4_5_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_4_6_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_5_0_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_5_1_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_5_2_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_5_3_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_5_4_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_5_5_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_5_6_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_6_0_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_6_1_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_6_2_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_6_3_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_6_4_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_6_5_pre.png
# Saved: ../data_secondary/pre/gaza_city_jabalya_6_6_pre.png
# Saved: ../data_secondary/pre/khan_yunis_0_0_pre.png
# Saved: ../data_secondary/pre/khan_yunis_0_1_pre.png
# Saved: ../data_secondary/pre/khan_yunis_0_2_pre.png
# Saved: ../data_secondary/pre/khan_yunis_0_3_pre.png
# Saved: ../data_secondary/pre/khan_yunis_0_4_pre.png
# Saved: ../data_secondary/pre/khan_yunis_0_5_pre.png
# Saved: ../data_secondary/pre/khan_yunis_0_6_pre.png
# Saved: ../data_secondary/pre/khan_yunis_1_0_pre.png
pre.png
# Saved: ../data_secondary/pre/beit_hanoun_1_2_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_1_3_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_1_4_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_1_5_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_1_6_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_2_0_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_2_1_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_2_2_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_2_3_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_2_4_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_2_5_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_2_6_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_3_0_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_3_1_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_3_2_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_3_3_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_3_4_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_3_5_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_3_6_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_4_0_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_4_1_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_4_2_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_4_3_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_4_4_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_4_5_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_4_6_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_5_0_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_5_1_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_5_2_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_5_3_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_5_4_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_5_5_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_5_6_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_6_0_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_6_1_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_6_2_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_6_3_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_6_4_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_6_5_pre.png
# Saved: ../data_secondary/pre/beit_hanoun_6_6_pre.png
# Saved: ../data_secondary/pre/rafah_0_0_pre.png
# Saved: ../data_secondary/pre/rafah_0_1_pre.png
# Saved: ../data_secondary/pre/rafah_0_2_pre.png
# Saved: ../data_secondary/pre/rafah_0_3_pre.png
# Saved: ../data_secondary/pre/rafah_0_4_pre.png
# Saved: ../data_secondary/pre/rafah_0_5_pre.png
# Saved: ../data_secondary/pre/rafah_0_6_pre.png
# Saved: ../data_secondary/pre/rafah_1_0_pre.png
# Saved: ../data_secondary/pre/rafah_1_1_pre.png
# Saved: ../data_secondary/pre/rafah_1_2_pre.png
# Saved: ../data_secondary/pre/rafah_1_3_pre.png
# Saved: ../data_secondary/pre/rafah_1_4_pre.png
# Saved: ../data_secondary/pre/rafah_1_5_pre.png
# Saved: ../data_secondary/pre/rafah_1_6_pre.png
# Saved: ../data_secondary/pre/rafah_2_0_pre.png
# Saved: ../data_secondary/pre/rafah_2_1_pre.png
# Saved: ../data_secondary/pre/rafah_2_2_pre.png
# Saved: ../data_secondary/pre/rafah_2_3_pre.png
# Saved: ../data_secondary/pre/rafah_2_4_pre.png
# Saved: ../data_secondary/pre/rafah_2_5_pre.png
# Saved: ../data_secondary/pre/rafah_2_6_pre.png
# Saved: ../data_secondary/pre/rafah_3_0_pre.png
# Saved: ../data_secondary/pre/rafah_3_1_pre.png
# Saved: ../data_secondary/pre/rafah_3_2_pre.png
# Saved: ../data_secondary/pre/rafah_3_3_pre.png
# Saved: ../data_secondary/pre/rafah_3_4_pre.png
# Saved: ../data_secondary/pre/rafah_3_5_pre.png
# Saved: ../data_secondary/pre/rafah_3_6_pre.png
# Saved: ../data_secondary/pre/rafah_4_0_pre.png
# Saved: ../data_secondary/pre/rafah_4_1_pre.png
# Saved: ../data_secondary/pre/rafah_4_2_pre.png
# Saved: ../data_secondary/pre/rafah_4_3_pre.png
# Saved: ../data_secondary/pre/rafah_4_4_pre.png
# Saved: ../data_secondary/pre/rafah_4_5_pre.png
# Saved: ../data_secondary/pre/rafah_4_6_pre.png
# Saved: ../data_secondary/pre/rafah_5_0_pre.png
# Saved: ../data_secondary/pre/rafah_5_1_pre.png
# Saved: ../data_secondary/pre/rafah_5_2_pre.png
# Saved: ../data_secondary/pre/rafah_5_3_pre.png
# Saved: ../data_secondary/pre/rafah_5_4_pre.png
# Saved: ../data_secondary/pre/rafah_5_5_pre.png
# Saved: ../data_secondary/pre/rafah_5_6_pre.png
# Saved: ../data_secondary/pre/rafah_6_0_pre.png
# Saved: ../data_secondary/pre/rafah_6_1_pre.png
# Saved: ../data_secondary/pre/rafah_6_2_pre.png
# Saved: ../data_secondary/pre/rafah_6_3_pre.png
# Saved: ../data_secondary/pre/rafah_6_4_pre.png
# Saved: ../data_secondary/pre/rafah_6_5_pre.png
# Saved: ../data_secondary/pre/rafah_6_6_pre.png
